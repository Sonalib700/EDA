# %%
import pandas as pd
import numpy as np

# %%
battle = pd.read_csv (r'C:\Users\Admin\Downloads\battles.csv')
battle
# Out:
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# 7                               Battle of Moat Cailin   299              8
# 8                            Battle of Deepwood Motte   299              9
# 9                           Battle of the Stony Shore   299             10
# 10                         Battle of Torrhen's Square   299             11
# ...

# %%
battle.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
battle.rename(columns={'attacker_1':'primary_attacker'},inplace=True)
battle
# Out:
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# 7                               Battle of Moat Cailin   299              8
# 8                            Battle of Deepwood Motte   299              9
# 9                           Battle of the Stony Shore   299             10
# 10                         Battle of Torrhen's Square   299             11
# ...

# %%
battle.shape
# Out:
# (38, 25)

# %%
battle.rename(columns={'defender_1':'primary_defender'},inplace=1)
battle
# Out:
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# 7                               Battle of Moat Cailin   299              8
# 8                            Battle of Deepwood Motte   299              9
# 9                           Battle of the Stony Shore   299             10
# 10                         Battle of Torrhen's Square   299             11
# ...

# %%
battle ['attacker_king'].value_counts()
# Out:
# attacker_king
# Joffrey/Tommen Baratheon    14
# Robb Stark                  10
# Balon/Euron Greyjoy          7
# Stannis Baratheon            5
# Name: count, dtype: int64

# %%
battle['year'].value_counts()
# Out:
# year
# 299    20
# 300    11
# 298     7
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(11,5)})
sns.barplot (x='attacker_king',y='attacker_size',data=battle)
# Out:
# C:\Users\Admin\.conda\Lib\site-packages\seaborn\algorithms.py:98: RuntimeWarning: Mean of empty slice
#   boot_dist.append(f(*sample, **func_kwargs))
# <Axes: xlabel='attacker_king', ylabel='attacker_size'>

# %%
battle['defender_size'] = pd.to_numeric(battle['defender_size'], errors='coerce').fillna(0).astype(int)
battle
# Out:
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# 7                               Battle of Moat Cailin   299              8
# 8                            Battle of Deepwood Motte   299              9
# 9                           Battle of the Stony Shore   299             10
# 10                         Battle of Torrhen's Square   299             11
# ...

# %%
x = battle['primary_defender']
y = battle[('defender_size')]
plt.bar('x','y')
plt.show()

# %%
battle ['location'].value_counts()
# Out:
# location
# Riverrun                                3
# Winterfell                              3
# Storm's End                             2
# Harrenhal                               2
# Darry                                   2
# Moat Cailin                             2
# Deepwood Motte                          2
# Torrhen's Square                        2
# Golden Tooth                            1
# Seagard                                 1
# Castle Black                            1
# Shield Islands                          1
# Saltpans                                1
# Ruby Ford                               1
# Ryamsport, Vinetown, Starfish Harbor    1
# Dragonstone                             1
# The Twins                               1
# Red Fork                                1
# Duskendale                              1
# King's Landing                          1
# Crag                                    1
# Mummer's Ford                           1
# ...

# %%
#plt.figure(figsize=(13, 4))
sns.set(rc={'figure.figsize': (13, 4)})
sns.barplot (x='defender_king',y='defender_size',data=battle)
# Out:
# <Axes: xlabel='defender_king', ylabel='defender_size'>

# %%
plt.bar(battle["defender_king"],battle["defender_size"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 plt.bar(battle["defender_king"],battle["defender_size"])
#       2 plt.show()
#
# File ~\.conda\Lib\site-packages\matplotlib\pyplot.py:2439, in bar(x, height, width, bottom, align, data, **kwargs)
#    2435 @_copy_docstring_and_deprecators(Axes.bar)
#    2436 def bar(
#    2437         x, height, width=0.8, bottom=None, *, align='center',
#    2438         data=None, **kwargs):
# -> 2439     return gca().bar(
#    2440         x, height, width=width, bottom=bottom, align=align,
#    2441         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~\.conda\Lib\site-packages\matplotlib\__init__.py:1446, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1443 @functools.wraps(func)
#    1444 def inner(ax, *args, data=None, **kwargs):
#    1445     if data is None:
# ...

# %%
battle ['location'].value_counts ()
# Out:
# location
# Riverrun                                3
# Winterfell                              3
# Storm's End                             2
# Harrenhal                               2
# Darry                                   2
# Moat Cailin                             2
# Deepwood Motte                          2
# Torrhen's Square                        2
# Golden Tooth                            1
# Seagard                                 1
# Castle Black                            1
# Shield Islands                          1
# Saltpans                                1
# Ruby Ford                               1
# Ryamsport, Vinetown, Starfish Harbor    1
# Dragonstone                             1
# The Twins                               1
# Red Fork                                1
# Duskendale                              1
# King's Landing                          1
# Crag                                    1
# Mummer's Ford                           1
# ...

# %%
battle
# Out:
#                                                  name  year  battle_number  \
# 0                          Battle of the Golden Tooth   298              1
# 1                         Battle at the Mummer's Ford   298              2
# 2                                  Battle of Riverrun   298              3
# 3                            Battle of the Green Fork   298              4
# 4                       Battle of the Whispering Wood   298              5
# 5                                 Battle of the Camps   298              6
# 6                                       Sack of Darry   298              7
# 7                               Battle of Moat Cailin   299              8
# 8                            Battle of Deepwood Motte   299              9
# 9                           Battle of the Stony Shore   299             10
# 10                         Battle of Torrhen's Square   299             11
# ...

# %%
deaths = pd.read_csv (r'C:\Users\Admin\Downloads\character-deaths.csv')
deaths
# Out:
#                         Name      Allegiances  Death Year  Book of Death  \
# 0             Addam Marbrand        Lannister         NaN            NaN
# 1    Aegon Frey (Jinglebell)              NaN       299.0            3.0
# 2            Aegon Targaryen  House Targaryen         NaN            NaN
# 3              Adrack Humble    House Greyjoy       300.0            5.0
# 4             Aemon Costayne        Lannister         NaN            NaN
# ..                       ...              ...         ...            ...
# 912                    Zollo              NaN         NaN            NaN
# 913        Yurkhaz zo Yunzak              NaN       300.0            5.0
# 914         Yezzan Zo Qaggaz              NaN       300.0            5.0
# 915         Torwynd the Tame         Wildling       300.0            5.0
# 916            Talbert Serry           Tyrell       300.0            4.0
#
#      Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# ...

# %%
deaths.head ()
# Out:
#                       Name      Allegiances  Death Year  Book of Death  \
# 0           Addam Marbrand        Lannister         NaN            NaN
# 1  Aegon Frey (Jinglebell)              NaN       299.0            3.0
# 2          Aegon Targaryen  House Targaryen         NaN            NaN
# 3            Adrack Humble    House Greyjoy       300.0            5.0
# 4           Aemon Costayne        Lannister         NaN            NaN
#
#    Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0            NaN                56.0       1         1    1    1    1    1
# 1           51.0                49.0       1         1    0    0    1    0
# 2            NaN                 5.0       1         1    0    0    0    0
# 3           20.0                20.0       1         1    0    0    0    0
# 4            NaN                 NaN       1         1    0    0    1    0
#
#    DwD
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0

# %%
deaths ['Gender'].value_counts()
# Out:
# Gender
# 1    760
# 0    157
# Name: count, dtype: int64

# %%
deaths ['Nobility'].value_counts()
# Out:
# Nobility
# 0    487
# 1    430
# Name: count, dtype: int64

# %%
sns.countplot (deaths['Death Year'])
plt.show()

# %%
sns.countplot (deaths['Allegiances'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 sns.countplot (deaths['Allegiances'])
#       2 plt.show()
#
# File ~\.conda\Lib\site-packages\seaborn\categorical.py:2943, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940 elif x is not None and y is not None:
#    2941     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2943 plotter = _CountPlotter(
#    2944     x, y, hue, data, order, hue_order,
#    2945     estimator, errorbar, n_boot, units, seed,
#    2946     orient, color, palette, saturation,
#    2947     width, errcolor, errwidth, capsize, dodge
#    2948 )
#    2950 plotter.value_label = "count"
#    2952 if ax is None:
#
# ...

# %%
data2 = pd.read_csv (r'C:\Users\Admin\Downloads\archive (5)\comic_characters.csv')
data2.head()
# Out:
#    Id                 Name Identity Alignment   Eyes   Hair     Sex Alive  \
# 0   0            Dave Finn   Secret      Good   Blue  Black    Male   Yes
# 1   1      Katherine Power   Secret      Good   Blue    Red  Female   Yes
# 2   2          John Malone   Secret       Bad   Blue  White    Male   Yes
# 3   3  Samuel Bradley, Jr.   Public       Bad  Brown  Brown    Male    No
# 4   4            Hope Taya   Public       Bad  Brown  Black  Female   Yes
#
#    Appearances  First_appeared     Planet Universe
# 0            1      2002, July  Earth-616   Marvel
# 1          106    1984, August  Earth-616   Marvel
# 2           15   1985, January  New Earth       DC
# 3           19     2004, March  New Earth       DC
# 4           28  1999, December  New Earth       DC

# %%
data2.shape
# Out:
# (21144, 12)

# %%
data2['Alignment'].value_counts()
# Out:
# Alignment
# Bad        10250
# Good        7957
# Neutral     2937
# Name: count, dtype: int64

# %%
good =  data2[data2['Alignment']=='Good']
good
# Out:
#           Id                        Name Identity Alignment   Eyes   Hair  \
# 0          0                   Dave Finn   Secret      Good   Blue  Black
# 1          1             Katherine Power   Secret      Good   Blue    Red
# 6          6  Boris Dmitravich Razumihin   Public      Good  Brown  Black
# 7          7                 Perry White   Public      Good   Blue  Brown
# 11        11            Vladimir Morakov   Public      Good  Black  Brown
# ...      ...                         ...      ...       ...    ...    ...
# 21133  21133               Rafael Carago   Secret      Good  White  Black
# 21138  21138                   Valtrauta   Secret      Good    Red  Blond
# 21141  21141                 Janet Grant   Public      Good  Brown  Black
# 21142  21142                Miya Shimada   Secret      Good  Brown  Black
# 21143  21143                       Loria   Secret      Good  Green  Black
#
#           Sex Alive  Appearances  First_appeared     Planet Universe
# ...

# %%
good.head()
# Out:
#     Id                        Name Identity Alignment   Eyes   Hair     Sex  \
# 0    0                   Dave Finn   Secret      Good   Blue  Black    Male
# 1    1             Katherine Power   Secret      Good   Blue    Red  Female
# 6    6  Boris Dmitravich Razumihin   Public      Good  Brown  Black    Male
# 7    7                 Perry White   Public      Good   Blue  Brown    Male
# 11  11            Vladimir Morakov   Public      Good  Black  Brown    Male
#
#    Alive  Appearances  First_appeared     Planet Universe
# 0    Yes            1      2002, July  Earth-616   Marvel
# 1    Yes          106    1984, August  Earth-616   Marvel
# 6    Yes            7  1987, December  New Earth       DC
# 7    Yes          350   1986, October  New Earth       DC
# 11   Yes            8  1989, December  New Earth       DC

# %%
good.sort_values(by=['Id'],ascending=True)
# Out:
#           Id                        Name Identity Alignment   Eyes   Hair  \
# 0          0                   Dave Finn   Secret      Good   Blue  Black
# 1          1             Katherine Power   Secret      Good   Blue    Red
# 6          6  Boris Dmitravich Razumihin   Public      Good  Brown  Black
# 7          7                 Perry White   Public      Good   Blue  Brown
# 11        11            Vladimir Morakov   Public      Good  Black  Brown
# ...      ...                         ...      ...       ...    ...    ...
# 21133  21133               Rafael Carago   Secret      Good  White  Black
# 21138  21138                   Valtrauta   Secret      Good    Red  Blond
# 21141  21141                 Janet Grant   Public      Good  Brown  Black
# 21142  21142                Miya Shimada   Secret      Good  Brown  Black
# 21143  21143                       Loria   Secret      Good  Green  Black
#
#           Sex Alive  Appearances  First_appeared     Planet Universe
# ...

# %%
good.sort_values(by=['Appearances'],ascending=True)
# Out:
#           Id                               Name Identity Alignment   Eyes  \
# 0          0                          Dave Finn   Secret      Good   Blue
# 4361    4361                        Amy Conklin   Secret      Good    Red
# 13209  13209  King and Queen of Barnyard Valley   Secret      Good   Blue
# 4349    4349                          Sunflower   Secret      Good   Blue
# 4348    4348                      Colonel Okada   Public      Good  Brown
# ...      ...                                ...      ...       ...    ...
# 14876  14876                           Superman   Secret      Good   Blue
# 2253    2253                           Iron Man   Public      Good   Blue
# 8155    8155                             Batman   Secret      Good   Blue
# 1114    1114                    Captain America   Public      Good   Blue
# 7518    7518                         Spider-Man   Secret      Good  Hazel
#
#         Hair      Sex Alive  Appearances First_appeared     Planet Universe
# ...

# %%
min_Appearances = data2 [data2['Appearances']==1]
min_Appearances
# Out:
#           Id           Name  Identity Alignment   Eyes   Hair     Sex Alive  \
# 0          0      Dave Finn    Secret      Good   Blue  Black    Male   Yes
# 8          8        Perkins    Public       Bad  Green  White  Female   Yes
# 15        15   Black Cougar  Non-dual       Bad  Black  Black    Male    No
# 27        27         String    Secret       Bad  Green  Brown    Male   Yes
# 28        28       Reynardo    Secret       Bad  Black  Brown    Male    No
# ...      ...            ...       ...       ...    ...    ...     ...   ...
# 21124  21124   Rodney Adams    Public   Neutral   Blue  Blond    Male   Yes
# 21127  21127    Eric Karlin    Public       Bad  Black  Brown    Male    No
# 21134  21134  Yoshida Asano    Public       Bad  Brown  Black    Male    No
# 21135  21135   Dennis Hoxie    Secret       Bad  Brown  Blond    Male   Yes
# 21141  21141    Janet Grant    Public      Good  Brown  Black  Female   Yes
#
#        Appearances   First_appeared     Planet Universe
# ...

# %%
part_Appearances = data2 [data2['Appearances']==2961]
part_Appearances
# Out:
#         Id      Name Identity Alignment  Eyes   Hair   Sex Alive  Appearances  \
# 2253  2253  Iron Man   Public      Good  Blue  Black  Male   Yes         2961
#
#      First_appeared   Planet Universe
# 2253    1963, March  Unknown   Marvel

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
good.head()
# Out:
#     Id                        Name Identity Alignment   Eyes   Hair     Sex  \
# 0    0                   Dave Finn   Secret      Good   Blue  Black    Male
# 1    1             Katherine Power   Secret      Good   Blue    Red  Female
# 6    6  Boris Dmitravich Razumihin   Public      Good  Brown  Black    Male
# 7    7                 Perry White   Public      Good   Blue  Brown    Male
# 11  11            Vladimir Morakov   Public      Good  Black  Brown    Male
#
#    Alive  Appearances  First_appeared     Planet Universe
# 0    Yes            1      2002, July  Earth-616   Marvel
# 1    Yes          106    1984, August  Earth-616   Marvel
# 6    Yes            7  1987, December  New Earth       DC
# 7    Yes          350   1986, October  New Earth       DC
# 11   Yes            8  1989, December  New Earth       DC

# %%
plt.figure(figsize=(11,5))
plt.bar ('Name','Appearances',data=good.head())
plt.show()

# %%
bad = data2[data2['Alignment']== 'Bad']
bad
# Out:
#           Id                 Name Identity Alignment   Eyes    Hair     Sex  \
# 2          2          John Malone   Secret       Bad   Blue   White    Male
# 3          3  Samuel Bradley, Jr.   Public       Bad  Brown   Brown    Male
# 4          4            Hope Taya   Public       Bad  Brown   Black  Female
# 5          5                Trygg   Secret       Bad  Black   Black    Male
# 8          8              Perkins   Public       Bad  Green   White  Female
# ...      ...                  ...      ...       ...    ...     ...     ...
# 21134  21134        Yoshida Asano   Public       Bad  Brown   Black    Male
# 21135  21135         Dennis Hoxie   Secret       Bad  Brown   Blond    Male
# 21136  21136     Silver St. Cloud   Public       Bad   Blue  Silver  Female
# 21139  21139       Winslow Schott   Public       Bad   Blue   Brown    Male
# 21140  21140           Jim Morita   Secret       Bad  Brown   Black    Male
#
# ...

# %%
bad.head()
# Out:
#    Id                 Name Identity Alignment   Eyes   Hair     Sex Alive  \
# 2   2          John Malone   Secret       Bad   Blue  White    Male   Yes
# 3   3  Samuel Bradley, Jr.   Public       Bad  Brown  Brown    Male    No
# 4   4            Hope Taya   Public       Bad  Brown  Black  Female   Yes
# 5   5                Trygg   Secret       Bad  Black  Black    Male   Yes
# 8   8              Perkins   Public       Bad  Green  White  Female   Yes
#
#    Appearances  First_appeared     Planet Universe
# 2           15   1985, January  New Earth       DC
# 3           19     2004, March  New Earth       DC
# 4           28  1999, December  New Earth       DC
# 5            3      1940, June  New Earth       DC
# 8            1   1964, October  Earth-616   Marvel
