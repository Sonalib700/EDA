# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv (r'C:\Users\Admin\Downloads\players_20.csv')
data
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
for col in data.columns:
    print (col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# ...

# %%
data.shape
# Out:
# (18278, 104)

# %%
data['nationality'].value_counts()
# Out:
# nationality
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: count, Length: 162, dtype: int64

# %%
data['nationality'].value_counts()[0:10]
# Out:
# nationality
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: count, dtype: int64

# %%
data['nationality'].value_counts()[0:10].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina', 'Brazil', 'Italy',
#        'Colombia', 'Japan', 'Netherlands'],
#       dtype='object', name='nationality')

# %%
plt.figure(figsize=(9,4))
plt.bar (list(data['nationality'].value_counts()[0:10].keys()),list(data['nationality'].value_counts()[0:10]),color='hotpink')
plt.show()

# %%
prayer_salary = data[['short_name','wage_eur']]
prayer_salary
# Out:
#               short_name  wage_eur
# 0               L. Messi    565000
# 1      Cristiano Ronaldo    405000
# 2              Neymar Jr    290000
# 3               J. Oblak    125000
# 4              E. Hazard    470000
# ...                  ...       ...
# 18273         Shao Shuai      2000
# 18274       Xiao Mingjie      2000
# 18275          Zhang Wei      1000
# 18276       Wang Haijian      1000
# 18277         Pan Ximing      2000
#
# [18278 rows x 2 columns]

# %%
prayer_salary.tail(10)
# Out:
#          short_name  wage_eur
# 18268  M. Gallagher      1000
# 18269  Huang Jiahui      1000
# 18270      M. Sagaf      1000
# 18271      E. Tweed      1000
# 18272     P. Martin      1000
# 18273    Shao Shuai      2000
# 18274  Xiao Mingjie      2000
# 18275     Zhang Wei      1000
# 18276  Wang Haijian      1000
# 18277    Pan Ximing      2000

# %%
prayer_salary = prayer_salary.sort_values (by = ['wage_eur'])
prayer_salary
# Out:
#               short_name  wage_eur
# 6415            C. Lampe         0
# 5600           A. Ashraf         0
# 13102           P. Bhatt         0
# 13103             B. Raj         0
# 3591            V. Belec         0
# ...                  ...       ...
# 5           K. De Bruyne    370000
# 22          A. Griezmann    370000
# 1      Cristiano Ronaldo    405000
# 4              E. Hazard    470000
# 0               L. Messi    565000
#
# [18278 rows x 2 columns]

# %%
prayer_salary.head(10)
# Out:
#        short_name  wage_eur
# 6415     C. Lampe         0
# 5600    A. Ashraf         0
# 13102    P. Bhatt         0
# 13103      B. Raj         0
# 3591     V. Belec         0
# 6833   L. Zahović         0
# 1539     H. Pérez         0
# 1502     I. Popov         0
# 8752   J. Breitez         0
# 3976    D. Dibusz         0

# %%
prayer_salary=prayer_salary.sort_values(by=['wage_eur'],ascending=False)
prayer_salary
# Out:
#               short_name  wage_eur
# 0               L. Messi    565000
# 4              E. Hazard    470000
# 1      Cristiano Ronaldo    405000
# 5           K. De Bruyne    370000
# 22          A. Griezmann    370000
# ...                  ...       ...
# 3591            V. Belec         0
# 13103             B. Raj         0
# 13102           P. Bhatt         0
# 5230          C. Lendezo         0
# 6415            C. Lampe         0
#
# [18278 rows x 2 columns]

# %%
prayer_salary.head (10)
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000
# 19          L. Suárez    355000
# 8           L. Modrić    340000
# 36           T. Kroos    330000
# 21    Sergio Busquets    300000
# 18       Sergio Ramos    300000

# %%
plt.figure (figsize = [12,5])
plt.bar (list(data['short_name'].value_counts()[0:10].keys()), list(data['short_name'].value_counts()[0:10]))
plt.show()

# %%
plt.figure (figsize = [12,5])
plt.bar (list(data['short_name'].value_counts()[0:10].keys()), list(data['short_name'].value_counts()[0:10]))
plt.show()

# %%
data
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
data ['nationality'] == 'Germany'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
Germany = data [data ['nationality'] == 'Germany']
Germany.head ()
# Out:
#     sofifa_id                                         player_url  \
# 6      192448  https://sofifa.com/player/192448/marc-andre-te...
# 31     167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37     188350  https://sofifa.com/player/188350/marco-reus/20...
# 49     178603  https://sofifa.com/player/178603/mats-hummels/...
#
#        short_name              long_name  age         dob  height_cm  \
# 6   M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 31       M. Neuer           Manuel Neuer   33  1986-03-27        193
# 36       T. Kroos             Toni Kroos   29  1990-01-04        183
# 37        M. Reus             Marco Reus   30  1989-05-31        180
# 49     M. Hummels          Mats  Hummels   30  1988-12-16        191
#
#     weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# 6          85     Germany       FC Barcelona  ...   NaN   NaN   NaN   NaN
# ...

# %%
Germany.sort_values (by = ['height_cm'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
#
#            short_name            long_name  age         dob  height_cm  \
# 8016        A. Seydel         Aaron Seydel   23  1996-02-07        199
# 1217         M. Esser        Michael Esser   31  1987-11-22        198
# 1389    L. Unnerstall      Lars Unnerstall   28  1990-07-20        198
# 11859  D. Stroh-Engel  Dominik Stroh-Engel   33  1985-11-27        197
# 13576    L. Watkowiak      Lukas Watkowiak   23  1996-03-06        197
#
#        weight_kg nationality                club  ...   lwb   ldm   cdm   rdm  \
# ...

# %%
Germany.sort_values (by = ['weight_kg'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...
#
#           short_name        long_name  age         dob  height_cm  weight_kg  \
# 13576   L. Watkowiak  Lukas Watkowiak   23  1996-03-06        197        103
# 1389   L. Unnerstall  Lars Unnerstall   28  1990-07-20        198        103
# 518      R. Fährmann    Ralf Fährmann   30  1988-09-27        197         98
# 1217        M. Esser    Michael Esser   31  1987-11-22        198         97
# 77           N. Süle      Niklas Süle   23  1995-09-03        195         97
#
#       nationality                club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %%
Germany.sort_values (by = ['age'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 15812     104900  https://sofifa.com/player/104900/michael-gursk...
# 12877     101317  https://sofifa.com/player/101317/michael-rataj...
# 3006      167452  https://sofifa.com/player/167452/oliver-fink/2...
# 10672     122066  https://sofifa.com/player/122066/ronny-konig/2...
# 12881     122718  https://sofifa.com/player/122718/philipp-heerw...
#
#          short_name          long_name  age         dob  height_cm  weight_kg  \
# 15812     M. Gurski     Michael Gurski   40  1979-03-21        189         89
# 12877  M. Ratajczak  Michael Ratajczak   37  1982-04-16        189         85
# 3006        O. Fink        Oliver Fink   37  1982-06-06        187         78
# 10672      R. König        Ronny König   36  1983-06-02        190         93
# 12881  P. Heerwagen  Philipp Heerwagen   36  1983-04-13        193         89
#
#       nationality                club  ...   lwb   ldm   cdm   rdm   rwb  \
# ...

# %%
data
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3         200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4         183277  https://sofifa.com/player/183277/eden-hazard/2...
# ...          ...                                                ...
# 18273     245006  https://sofifa.com/player/245006/shuai-shao/20...
# 18274     250995  https://sofifa.com/player/250995/mingjie-xiao/...
# 18275     252332  https://sofifa.com/player/252332/wei-zhang/20/...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# ...

# %%
# calculate german player with highest height
Germany_tallest = data [['nationality','height_cm']]
Germany_tallest ['nationality']== 'Germany'
G = Germany_tallest [Germany_tallest ['nationality'] == 'Germany']
G.sort_values (by = 'height_cm', ascending=False).head (5)
# Out:
#       nationality  height_cm
# 8016      Germany        199
# 1217      Germany        198
# 1389      Germany        198
# 11859     Germany        197
# 13576     Germany        197

# %%
player_shooting = data [['short_name','shooting']]
player_shooting
# Out:
#               short_name  shooting
# 0               L. Messi      92.0
# 1      Cristiano Ronaldo      93.0
# 2              Neymar Jr      85.0
# 3               J. Oblak       NaN
# 4              E. Hazard      83.0
# ...                  ...       ...
# 18273         Shao Shuai      23.0
# 18274       Xiao Mingjie      24.0
# 18275          Zhang Wei      35.0
# 18276       Wang Haijian      35.0
# 18277         Pan Ximing      32.0
#
# [18278 rows x 2 columns]

# %%
# calculate aged member of Brazil
B = data [['age','nationality']]
Aged_member= B [B['nationality']== 'Brazil']
Aged_member.sort_values (by = 'age',ascending=False).head(1)
# Out:
#      age nationality
# 868   41      Brazil
